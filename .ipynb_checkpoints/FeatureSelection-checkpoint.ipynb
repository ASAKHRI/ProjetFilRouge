# %%
import pandas as pd
# visualisation
import matplotlib.pyplot as plt
import seaborn as sns
#stats
from scipy.stats import chi2_contingency
from scipy.stats import f_oneway, levene, shapiro, kruskal, mannwhitneyu, ttest_ind


#reduction de diomention
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('data/dataEnriched.csv')
data.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
# 3               Y             0          135000.0    312682.5      29686.5
# 4               Y             0          121500.0    513000.0      21865.5
#
#    ...  ANNUITY_SUM_ALL ANNUITY_GOODS_SUM_ALL  \
# 0  ...     7.460622e+03          7.460622e+03
# 1  ...     1.501007e+05          1.369840e+05
# 2  ...     5.026487e+03          6.070485e+03
# 3  ...     2.700008e+10          2.700008e+10
# 4  ...     4.935926e+04          4.617637e+04
#
#   AMT_CREDIT_HOUR_PROCESS_START_MEAN_ALL  \
# 0                             1611495.00
# 1                             6459408.00
# 2                              100530.00
# 3                             4214934.00
# 4                             1935207.75
#
#   AMT_CREDIT_HOUR_PROCESS_START_SUM_ALL  \
# 0                             1611495.0
# 1                            19378224.0
# 2                              100530.0
# 3                            37934406.0
# 4                            11611246.5
#
#   AMT_CREDIT_NFLAG_LAST_APPL_DAY_MEAN_ALL  \
# 0                               179055.00
# 1                               484191.00
# 2                                20106.00
# 3                               291695.50
# 4                               166638.75
#
#   AMT_CREDIT_NFLAG_LAST_APPL_DAY_MAX_ALL  AMT_CREDIT_YIELD_GROUP_MEAN_ALL  \
# 0                               179055.0                        358110.00
# 1                              1035882.0                       1107279.00
# 2                                20106.0                         60318.00
# 3                               906615.0                        692621.00
# 4                               284400.0                        537462.75
#
#    AMT_CREDIT_YIELD_GROUP_SUM_ALL  AMT_CREDIT_YIELD_GROUP_MIN_ALL  \
# 0                        358110.0                        358110.0
# 1                       3321837.0                        204160.5
# 2                         60318.0                         60318.0
# 3                       6233589.0                             0.0
# 4                       3224776.5                         58464.0
#
#    AMT_INTEREST_SUM_ALL
# 0              42987.60
# 1             195964.65
# 2               1323.00
# 3            1205267.76
# 4             640477.62
#
# [5 rows x 377 columns]

# %%
data['TARGET'] = data['TARGET'].astype('object')

# %%
colCat = data.select_dtypes(include = 'object')

# %%
colCat.columns
# Out:
# Index(['TARGET', 'NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR',
#        'FLAG_OWN_REALTY', 'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE',
#        'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE',
#        'OCCUPATION_TYPE', 'WEEKDAY_APPR_PROCESS_START', 'ORGANIZATION_TYPE',
#        'FONDKAPREMONT_MODE', 'HOUSETYPE_MODE', 'WALLSMATERIAL_MODE',
#        'EMERGENCYSTATE_MODE'],
#       dtype='object')

# %%
colName = ['TARGET', 'NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR',
       'FLAG_OWN_REALTY', 'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE',
       'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE',
       'OCCUPATION_TYPE', 'WEEKDAY_APPR_PROCESS_START', 'ORGANIZATION_TYPE',
       'FONDKAPREMONT_MODE', 'HOUSETYPE_MODE', 'WALLSMATERIAL_MODE',
       'EMERGENCYSTATE_MODE']
for col in colName:
    print(data[col].value_counts())
# Out:
# Cash loans         278232
# Revolving loans     29275
# Name: NAME_CONTRACT_TYPE, dtype: int64
# F    202448
# M    105059
# Name: CODE_GENDER, dtype: int64
# N    202922
# Y    104585
# Name: FLAG_OWN_CAR, dtype: int64
# Y    213308
# N     94199
# Name: FLAG_OWN_REALTY, dtype: int64
# Unaccompanied      248523
# Family              40148
# Spouse, partner     11370
# Children             3267
# Other_B              1770
# XNA                  1292
# Other_A               866
# Group of people       271
# Name: NAME_TYPE_SUITE, dtype: int64
# Working                 158771
# Commercial associate     71616
# Pensioner                55362
# State servant            21703
# Unemployed                  22
# Student                     18
# Businessman                 10
# Maternity leave              5
# Name: NAME_INCOME_TYPE, dtype: int64
# Secondary / secondary special    218389
# Higher education                  74862
# Incomplete higher                 10276
# Lower secondary                    3816
# Academic degree                     164
# Name: NAME_EDUCATION_TYPE, dtype: int64
# Married                 196429
# Single / not married     45444
# Civil marriage           29774
# Separated                19770
# Widow                    16088
# Unknown                      2
# Name: NAME_FAMILY_STATUS, dtype: int64
# House / apartment      272865
# With parents            14840
# Municipal apartment     11182
# Rented apartment         4881
# Office apartment         2617
# Co-op apartment          1122
# Name: NAME_HOUSING_TYPE, dtype: int64
# XNA                      96389
# Laborers                 55186
# Sales staff              32102
# Core staff               27569
# Managers                 21371
# Drivers                  18603
# High skill tech staff    11380
# Accountants               9813
# Medicine staff            8537
# Security staff            6721
# Cooking staff             5946
# Cleaning staff            4653
# Private service staff     2652
# Low-skill Laborers        2092
# Waiters/barmen staff      1348
# Secretaries               1305
# Realty agents              751
# HR staff                   563
# IT staff                   526
# Name: OCCUPATION_TYPE, dtype: int64
# TUESDAY      53900
# WEDNESDAY    51934
# MONDAY       50714
# THURSDAY     50590
# FRIDAY       50336
# SATURDAY     33852
# SUNDAY       16181
# Name: WEEKDAY_APPR_PROCESS_START, dtype: int64
# Business Entity Type 3    67992
# XNA                       55374
# Self-employed             38412
# Other                     16683
# Medicine                  11192
# Business Entity Type 2    10553
# Government                10404
# School                     8893
# Trade: type 7              7831
# Kindergarten               6879
# Construction               6721
# Business Entity Type 1     5983
# Transport: type 4          5398
# Trade: type 3              3492
# Industry: type 9           3368
# Industry: type 3           3277
# Security                   3247
# Housing                    2958
# Industry: type 11          2704
# Military                   2634
# Bank                       2507
# Agriculture                2454
# Police                     2341
# Transport: type 2          2204
# Postal                     2157
# Security Ministries        1974
# Trade: type 2              1900
# Restaurant                 1811
# Services                   1575
# University                 1327
# Industry: type 7           1307
# Transport: type 3          1187
# Industry: type 1           1039
# Hotel                       966
# Electricity                 950
# Industry: type 4            877
# Trade: type 6               631
# Industry: type 5            599
# Insurance                   597
# Telecom                     577
# Emergency                   560
# Industry: type 2            458
# Advertising                 429
# Realtor                     396
# Culture                     379
# Industry: type 12           369
# Trade: type 1               348
# Mobile                      317
# Legal Services              305
# Cleaning                    260
# Transport: type 1           201
# Industry: type 6            112
# Industry: type 10           109
# Religion                     85
# Industry: type 13            67
# Trade: type 4                64
# Trade: type 5                49
# Industry: type 8             24
# Name: ORGANIZATION_TYPE, dtype: int64
# XNA                      210293
# reg oper account          73829
# reg oper spec account     12079
# not specified              5687
# org spec account           5619
# Name: FONDKAPREMONT_MODE, dtype: int64
# XNA                 154296
# block of flats      150500
# specific housing      1499
# terraced house        1212
# Name: HOUSETYPE_MODE, dtype: int64
# XNA             156340
# Panel            66039
# Stone, brick     64813
# Block             9253
# Wooden            5362
# Mixed             2296
# Monolithic        1779
# Others            1625
# Name: WALLSMATERIAL_MODE, dtype: int64
# No     159425
# XNA    145754
# Yes      2328
# Name: EMERGENCYSTATE_MODE, dtype: int64

# %%
# Sélectionner les colonnes d'intérêt
colName = ['TARGET', 'NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR',
       'FLAG_OWN_REALTY', 'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE',
       'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE',
       'OCCUPATION_TYPE', 'WEEKDAY_APPR_PROCESS_START', 'ORGANIZATION_TYPE',
       'FONDKAPREMONT_MODE', 'HOUSETYPE_MODE', 'WALLSMATERIAL_MODE',
       'EMERGENCYSTATE_MODE']
# Créer un DataFrame avec seulement les colonnes d'intérêt
data_sub = data[colName]

# Liste des colonnes catégorielles
cat_columns = ['TARGET', 'NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR',
       'FLAG_OWN_REALTY', 'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE',
       'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE',
       'OCCUPATION_TYPE', 'WEEKDAY_APPR_PROCESS_START', 'ORGANIZATION_TYPE',
       'FONDKAPREMONT_MODE', 'HOUSETYPE_MODE', 'WALLSMATERIAL_MODE',
       'EMERGENCYSTATE_MODE']

# Réaliser le test du Chi-deux pour chaque colonne catégorielle
for col in cat_columns:
    contingency_table = pd.crosstab(data_sub[col], data_sub['TARGET'])
    chi2, p, dof, expected = chi2_contingency(contingency_table)
    print(f"Relation entre {col} et la TARGET :")
    print(f"Statistique Chi-deux : {chi2}")
    print(f"p-value : {p}")
    print(f"Degrés de liberté : {dof}")
    print("Fréquences attendues :")
    print(expected)
    print("\n")
# Out:
# Relation entre TARGET et la TARGET :
# Statistique Chi-deux : 307493.5253391637
# p-value : 0.0
# Degrés de liberté : 1
# Fréquences attendues :
# [[259861.11901192  22820.88098808]
#  [ 22820.88098808   2004.11901192]]
#
#
# Relation entre NAME_CONTRACT_TYPE et la TARGET :
# Statistique Chi-deux : 292.95767617018174
# p-value : 1.1274999190439246e-65
# Degrés de liberté : 1
# Fréquences attendues :
# [[255770.36693148  22461.63306852]
#  [ 26911.63306852   2363.36693148]]
#
#
# Relation entre CODE_GENDER et la TARGET :
# Statistique Chi-deux : 920.0057254249849
# p-value : 4.394091339983112e-202
# Degrés de liberté : 1
# Fréquences attendues :
# [[186104.39936652  16343.60063348]
#  [ 96577.60063348   8481.39936652]]
#
#
# Relation entre FLAG_OWN_CAR et la TARGET :
# Statistique Chi-deux : 146.63914697498637
# p-value : 9.410574445435375e-34
# Degrés de liberté : 1
# Fréquences attendues :
# [[186540.13340835  16381.86659165]
#  [ 96141.86659165   8443.13340835]]
#
#
# Relation entre FLAG_OWN_REALTY et la TARGET :
# Statistique Chi-deux : 11.56609246221532
# p-value : 0.0006716541669272181
# Degrés de liberté : 1
# Fréquences attendues :
# [[ 86594.32701695   7604.67298305]
#  [196087.67298305  17220.32701695]]
#
#
# Relation entre NAME_TYPE_SUITE et la TARGET :
# Statistique Chi-deux : 45.18462657809335
# p-value : 1.2592553154137952e-07
# Degrés de liberté : 7
# Fréquences attendues :
# [[3.00325552e+03 2.63744484e+02]
#  [3.69068572e+04 3.24114280e+03]
#  [2.49122205e+02 2.18777947e+01]
#  [7.96087933e+02 6.99120670e+01]
#  [1.62710813e+03 1.42891869e+02]
#  [1.04521014e+04 9.17898617e+02]
#  [2.28459771e+05 2.00632294e+04]
#  [1.18769701e+03 1.04302991e+02]]
#
#
# Relation entre NAME_INCOME_TYPE et la TARGET :
# Statistique Chi-deux : 1253.5518049423504
# p-value : 1.851917468924633e-266
# Degrés de liberté : 7
# Fréquences attendues :
# [[9.19270130e+00 8.07298696e-01]
#  [6.58344497e+04 5.78155034e+03]
#  [4.59635065e+00 4.03649348e-01]
#  [5.08926330e+04 4.46936704e+03]
#  [1.99509196e+04 1.75208036e+03]
#  [1.65468623e+01 1.45313765e+00]
#  [2.02239429e+01 1.77605713e+00]
#  [1.45953438e+05 1.28175621e+04]]
#
#
# Relation entre NAME_EDUCATION_TYPE et la TARGET :
# Statistique Chi-deux : 1019.2008734583078
# p-value : 2.4627681872810625e-219
# Degrés de liberté : 4
# Fréquences attendues :
# [[1.50760301e+02 1.32396986e+01]
#  [6.88184005e+04 6.04359950e+03]
#  [9.44641986e+03 8.29580140e+02]
#  [3.50793482e+03 3.08065182e+02]
#  [2.00758485e+05 1.76305155e+04]]
#
#
# Relation entre NAME_FAMILY_STATUS et la TARGET :
# Statistique Chi-deux : 504.70111951321655
# p-value : 7.717800159426535e-107
# Degrés de liberté : 5
# Fréquences attendues :
# [[2.73703489e+04 2.40365114e+03]
#  [1.80571312e+05 1.58576875e+04]
#  [1.81739705e+04 1.59602952e+03]
#  [4.17753118e+04 3.66868819e+03]
#  [1.83854026e+00 1.61459739e-01]
#  [1.47892179e+04 1.29878214e+03]]
#
#
# Relation entre NAME_HOUSING_TYPE et la TARGET :
# Statistique Chi-deux : 420.5438776545346
# p-value : 1.1058276330411493e-88
# Degrés de liberté : 5
# Fréquences attendues :
# [[1.03142109e+03 9.05789137e+01]
#  [2.50836644e+05 2.20283559e+04]
#  [1.02792786e+04 9.02721401e+02]
#  [2.40572993e+03 2.11270069e+02]
#  [4.48695751e+03 3.94042493e+02]
#  [1.36419687e+04 1.19803126e+03]]
#
#
# Relation entre OCCUPATION_TYPE et la TARGET :
# Statistique Chi-deux : 1975.2725416876456
# p-value : 0.0
# Degrés de liberté : 18
# Fréquences attendues :
# [[9.02079779e+03 7.92202210e+02]
#  [4.27736392e+03 3.75636083e+02]
#  [5.46598020e+03 4.80019804e+02]
#  [2.53433582e+04 2.22564177e+03]
#  [1.71011822e+04 1.50181776e+03]
#  [5.17549083e+02 4.54509166e+01]
#  [1.04612941e+04 9.18705916e+02]
#  [4.83536089e+02 4.24639114e+01]
#  [5.07308414e+04 4.45515858e+03]
#  [1.92311311e+03 1.68886887e+02]
#  [1.96457220e+04 1.72527804e+03]
#  [7.84780910e+03 6.89190896e+02]
#  [2.43790439e+03 2.14095614e+02]
#  [6.90371868e+02 6.06281320e+01]
#  [2.95104097e+04 2.59159027e+03]
#  [1.19964752e+03 1.05352480e+02]
#  [6.17841455e+03 5.42585453e+02]
#  [1.23917614e+03 1.08823864e+02]
#  [8.86075286e+04 7.78147140e+03]]
#
#
# Relation entre WEEKDAY_APPR_PROCESS_START et la TARGET :
# Statistique Chi-deux : 15.39735714902999
# p-value : 0.01738140590395065
# Degrés de liberté : 6
# Fréquences attendues :
# [[46272.38128563  4063.61871437]
#  [46619.86539493  4094.13460507]
#  [31119.13245552  2732.86754448]
#  [14874.70998059  1306.29001941]
#  [46505.87589876  4084.12410124]
#  [49548.6600305   4351.3399695 ]
#  [47741.37495407  4192.62504593]]
#
#
# Relation entre ORGANIZATION_TYPE et la TARGET :
# Statistique Chi-deux : 1609.2365657520058
# p-value : 5.234820758918666e-299
# Degrés de liberté : 57
# Fréquences attendues :
# [[3.94366886e+02 3.46331140e+01]
#  [2.25588890e+03 1.98111100e+02]
#  [2.30461022e+03 2.02389783e+02]
#  [5.49999319e+03 4.83006810e+02]
#  [9.70105769e+03 8.51942314e+02]
#  [6.25030147e+04 5.48898529e+03]
#  [2.39010234e+02 2.09897661e+01]
#  [6.17841455e+03 5.42585453e+02]
#  [3.48403379e+02 3.05966206e+01]
#  [8.73306624e+02 7.66933761e+01]
#  [5.14791273e+02 4.52087270e+01]
#  [9.56408644e+03 8.39913563e+02]
#  [8.88014946e+02 7.79850540e+01]
#  [2.71920105e+03 2.38798954e+02]
#  [9.55121666e+02 8.38783345e+01]
#  [1.00200444e+02 8.79955578e+00]
#  [2.48570643e+03 2.18293567e+02]
#  [3.39210678e+02 2.97893219e+01]
#  [6.15910987e+01 5.40890126e+00]
#  [4.21025720e+02 3.69742803e+01]
#  [3.01244822e+03 2.64551783e+02]
#  [8.06199904e+02 7.08000956e+01]
#  [5.50642808e+02 4.83571919e+01]
#  [1.02958255e+02 9.04174539e+00]
#  [1.20148606e+03 1.05513940e+02]
#  [2.20624831e+01 1.93751687e+00]
#  [3.09610180e+03 2.71898201e+02]
#  [5.48804268e+02 4.81957321e+01]
#  [6.32365923e+03 5.55340773e+02]
#  [2.80377390e+02 2.46226102e+01]
#  [1.02884713e+04 9.03528700e+02]
#  [2.42135752e+03 2.12642476e+02]
#  [2.91408631e+02 2.55913687e+01]
#  [1.53361836e+04 1.34681641e+03]
#  [2.15201138e+03 1.88988625e+02]
#  [1.98286567e+03 1.74134329e+02]
#  [3.64030972e+02 3.19690283e+01]
#  [7.81379611e+01 6.86203891e+00]
#  [1.66479821e+03 1.46201794e+02]
#  [8.17506927e+03 7.17930730e+02]
#  [2.98487011e+03 2.62129886e+02]
#  [1.81463924e+03 1.59360763e+02]
#  [3.53110043e+04 3.10099575e+03]
#  [1.44785046e+03 1.27149545e+02]
#  [5.30418865e+02 4.65811347e+01]
#  [3.19906005e+02 2.80939946e+01]
#  [1.74661325e+03 1.53386752e+02]
#  [3.21009130e+03 2.81908705e+02]
#  [5.88332883e+01 5.16671165e+00]
#  [4.50442364e+01 3.95576361e+00]
#  [5.80059452e+02 5.09405477e+01]
#  [7.19880439e+03 6.32195609e+02]
#  [1.84773296e+02 1.62267038e+01]
#  [2.02607137e+03 1.77928633e+02]
#  [1.09117364e+03 9.58263552e+01]
#  [4.96222016e+03 4.35779836e+02]
#  [1.21987146e+03 1.07128537e+02]
#  [5.09036642e+04 4.47033580e+03]]
#
#
# Relation entre FONDKAPREMONT_MODE et la TARGET :
# Statistique Chi-deux : 281.6854970468484
# p-value : 9.651140505149406e-60
# Degrés de liberté : 4
# Fréquences attendues :
# [[193316.07353979  16976.92646021]
#  [  5227.88923179    459.11076821]
#  [  5165.37886292    453.62113708]
#  [ 67868.79445996   5960.20554004]
#  [ 11103.86390554    975.13609446]]
#
#
# Relation entre HOUSETYPE_MODE et la TARGET :
# Statistique Chi-deux : 509.3555048154593
# p-value : 4.478763887714343e-110
# Degrés de liberté : 3
# Fréquences attendues :
# [[1.41839704e+05 1.24562960e+04]
#  [1.38350155e+05 1.21498454e+04]
#  [1.37798593e+03 1.21014074e+02]
#  [1.11415540e+03 9.78446019e+01]]
#
#
# Relation entre WALLSMATERIAL_MODE et la TARGET :
# Statistique Chi-deux : 598.9973766374208
# p-value : 4.0032397173444257e-125
# Degrés de liberté : 7
# Fréquences attendues :
# [[8.50600652e+03 7.46993483e+02]
#  [2.11064422e+03 1.85355781e+02]
#  [1.63538156e+03 1.43618438e+02]
#  [1.49381396e+03 1.31186038e+02]
#  [6.07076801e+04 5.33131986e+03]
#  [5.95806550e+04 5.23234504e+03]
#  [4.92912644e+03 4.32873561e+02]
#  [1.43718692e+05 1.26213078e+04]]
#
#
# Relation entre EMERGENCYSTATE_MODE et la TARGET :
# Statistique Chi-deux : 547.9298864859311
# p-value : 1.0436068346062157e-119
# Degrés de liberté : 2
# Fréquences attendues :
# [[146554.64054477  12870.35945523]
#  [133987.29859158  11766.70140842]
#  [  2140.06086366    187.93913634]]

# %% [markdown]
# une p_value faible (>5%) signifie que la target et la variable categorielle ne sont pas independantes
# nous allons donc par la suite supprimer les variables avec des p_value depassant le seuil des 5%

# %%
# Sélectionner les colonnes numériques
numerical_columns = data.select_dtypes(exclude=['object']).columns

# Séparer les données en deux groupes selon la TARGET
group1 = data[data['TARGET'] == 0]
group2 = data[data['TARGET'] == 1] 

# Vérifier les conditions pour l'utilisation de l'ANOVA
def check_anova_conditions(group1, group2, numerical_column):
    # Vérifier l'homogénéité des variances
    levene_stat, levene_pvalue = levene(group1[numerical_column], group2[numerical_column])
    
    # Vérifier la normalité des résidus
    shapiro_stat_group1, shapiro_pvalue_group1 = shapiro(group1[numerical_column])
    shapiro_stat_group2, shapiro_pvalue_group2 = shapiro(group2[numerical_column])
    
    return (levene_pvalue > 0.05) and (shapiro_pvalue_group1 > 0.05) and (shapiro_pvalue_group2 > 0.05)

# Appliquer l'ANOVA pour chaque caractéristique numérique
for column in numerical_columns:
    if check_anova_conditions(group1, group2, column):  
        stat, p = f_oneway(group1[column], group2[column])
        print(f"Relation entre {column} et la TARGET :")
        print(f"Statistique ANOVA : {stat}")
        print(f"p-value : {p}")
        print("\n")
    else:
        print(f"Les conditions pour l'ANOVA ne sont pas remplies pour {column}.")
        print("\n")
# Out:
# C:\Users\najibou\anaconda3\lib\site-packages\scipy\stats\_morestats.py:1800: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# Les conditions pour l'ANOVA ne sont pas remplies pour SK_ID_CURR.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CNT_CHILDREN.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_INCOME_TOTAL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_ANNUITY.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_GOODS_PRICE.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour REGION_POPULATION_RELATIVE.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour DAYS_BIRTH.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour DAYS_EMPLOYED.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour DAYS_REGISTRATION.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour DAYS_ID_PUBLISH.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour FLAG_MOBIL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour FLAG_EMP_PHONE.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour FLAG_WORK_PHONE.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour FLAG_CONT_MOBILE.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour FLAG_PHONE.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour FLAG_EMAIL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CNT_FAM_MEMBERS.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour REGION_RATING_CLIENT.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour REGION_RATING_CLIENT_W_CITY.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour HOUR_APPR_PROCESS_START.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour REG_REGION_NOT_LIVE_REGION.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour REG_REGION_NOT_WORK_REGION.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour LIVE_REGION_NOT_WORK_REGION.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour REG_CITY_NOT_LIVE_CITY.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour REG_CITY_NOT_WORK_CITY.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour LIVE_CITY_NOT_WORK_CITY.
# C:\Users\najibou\anaconda3\lib\site-packages\scipy\stats\_morestats.py:1797: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# Les conditions pour l'ANOVA ne sont pas remplies pour EXT_SOURCE_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour EXT_SOURCE_3.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour OBS_30_CNT_SOCIAL_CIRCLE.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour DEF_30_CNT_SOCIAL_CIRCLE.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour OBS_60_CNT_SOCIAL_CIRCLE.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour DEF_60_CNT_SOCIAL_CIRCLE.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour DAYS_LAST_PHONE_CHANGE.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour FLAG_DOCUMENT_3.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour FLAG_DOCUMENT_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour FLAG_DOCUMENT_6.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour FLAG_DOCUMENT_7.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour FLAG_DOCUMENT_8.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour FLAG_DOCUMENT_9.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour FLAG_DOCUMENT_11.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour FLAG_DOCUMENT_13.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour FLAG_DOCUMENT_14.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour FLAG_DOCUMENT_15.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour FLAG_DOCUMENT_16.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour FLAG_DOCUMENT_17.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour FLAG_DOCUMENT_18.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour FLAG_DOCUMENT_19.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour FLAG_DOCUMENT_21.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_REQ_CREDIT_BUREAU_HOUR.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_REQ_CREDIT_BUREAU_DAY.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_REQ_CREDIT_BUREAU_WEEK.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_REQ_CREDIT_BUREAU_MON.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_REQ_CREDIT_BUREAU_QRT.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_REQ_CREDIT_BUREAU_YEAR.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour MISSING_VALS_TOTAL_APP.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CREDIT_INCOME_RATIO.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CREDIT_ANNUITY_RATIO.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour ANNUITY_INCOME_RATIO.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour INCOME_ANNUITY_DIFF.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CREDIT_GOODS_RATIO.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CREDIT_GOODS_DIFF.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour GOODS_INCOME_RATIO.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour INCOME_EXT_RATIO.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CREDIT_EXT_RATIO.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AGE_EMPLOYED_DIFF.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour EMPLOYED_TO_AGE_RATIO.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour FLAG_CONTACTS_SUM.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour HOUR_PROCESS_CREDIT_MUL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CNT_NON_CHILDREN.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CHILDREN_INCOME_RATIO.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour PER_CAPITA_INCOME.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour REGIONS_RATING_INCOME_MUL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour REGION_RATING_MAX.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour REGION_RATING_MEAN.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour REGION_RATING_MUL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour FLAG_REGIONS.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour OBS_30_60_SUM.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour DEF_30_60_SUM.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour OBS_DEF_30_MUL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour OBS_DEF_60_MUL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour SUM_OBS_DEF_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour OBS_30_CREDIT_RATIO.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour OBS_60_CREDIT_RATIO.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour DEF_30_CREDIT_RATIO.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour DEF_60_CREDIT_RATIO.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour SUM_FLAGS_DOCUMENTS.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour DAYS_DETAILS_CHANGE_MUL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour DAYS_DETAILS_CHANGE_SUM.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_ENQ_SUM.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour ENQ_CREDIT_RATIO.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour DAYS_CREDIT_MEAN_OVERALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CREDIT_DAY_OVERDUE_MEAN_OVERALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CNT_CREDIT_PROLONG_MEAN_OVERALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_SUM_MEAN_OVERALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_SUM_DEBT_MEAN_OVERALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_SUM_OVERDUE_MEAN_OVERALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour FLAG_OVERDUE_RECENT_MEAN_OVERALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CURRENT_DEBT_TO_CREDIT_RATIO_MEAN_OVERALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CURRENT_CREDIT_DEBT_DIFF_MEAN_OVERALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CURRENCY_currency 1_MEAN_OVERALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CURRENCY_currency 2_MEAN_OVERALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CURRENCY_currency 3_MEAN_OVERALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CURRENCY_currency 4_MEAN_OVERALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CREDIT_ACTIVE_Active_MEAN_OVERALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CREDIT_ACTIVE_Bad debt_MEAN_OVERALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CREDIT_ACTIVE_Closed_MEAN_OVERALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CREDIT_ACTIVE_Sold_MEAN_OVERALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CREDIT_TYPE_Another type of loan_MEAN_OVERALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CREDIT_TYPE_Car loan_MEAN_OVERALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CREDIT_TYPE_Cash loan (non-earmarked)_MEAN_OVERALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CREDIT_TYPE_Consumer credit_MEAN_OVERALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CREDIT_TYPE_Credit card_MEAN_OVERALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CREDIT_TYPE_Interbank credit_MEAN_OVERALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CREDIT_TYPE_Loan for business development_MEAN_OVERALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CREDIT_TYPE_Loan for purchase of shares (margin lending)_MEAN_OVERALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CREDIT_TYPE_Loan for the purchase of equipment_MEAN_OVERALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CREDIT_TYPE_Loan for working capital replenishment_MEAN_OVERALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CREDIT_TYPE_Microloan_MEAN_OVERALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CREDIT_TYPE_Mobile operator loan_MEAN_OVERALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CREDIT_TYPE_Mortgage_MEAN_OVERALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CREDIT_TYPE_Real estate loan_MEAN_OVERALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CREDIT_TYPE_Unknown type of loan_MEAN_OVERALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour MISSING_VALUES_TOTAL_PREV_SUM_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_CONTRACT_TYPE_MEAN_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_CONTRACT_TYPE_LAST_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_ANNUITY_SUM_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_APPLICATION_MEAN_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_APPLICATION_MAX_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_APPLICATION_SUM_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_MEAN_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_MAX_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_SUM_LAST_5.
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_DOWN_PAYMENT_SUM_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_GOODS_PRICE_SUM_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour WEEKDAY_APPR_PROCESS_START_MEAN_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour WEEKDAY_APPR_PROCESS_START_MAX_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour WEEKDAY_APPR_PROCESS_START_MIN_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour HOUR_APPR_PROCESS_START_MEAN_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour HOUR_APPR_PROCESS_START_MAX_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour HOUR_APPR_PROCESS_START_MIN_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour FLAG_LAST_APPL_PER_CONTRACT_MEAN_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour FLAG_LAST_APPL_PER_CONTRACT_SUM_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NFLAG_LAST_APPL_IN_DAY_MEAN_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NFLAG_LAST_APPL_IN_DAY_SUM_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_CASH_LOAN_PURPOSE_MEAN_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_CASH_LOAN_PURPOSE_LAST_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_CONTRACT_STATUS_MEAN_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_CONTRACT_STATUS_MAX_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_CONTRACT_STATUS_LAST_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour DAYS_DECISION_MEAN_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour DAYS_DECISION_MAX_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour DAYS_DECISION_MIN_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_PAYMENT_TYPE_MEAN_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_PAYMENT_TYPE_LAST_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CODE_REJECT_REASON_MEAN_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CODE_REJECT_REASON_LAST_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_TYPE_SUITE_MEAN_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_TYPE_SUITE_LAST_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_CLIENT_TYPE_MEAN_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_CLIENT_TYPE_LAST_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_GOODS_CATEGORY_MEAN_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_GOODS_CATEGORY_LAST_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_PORTFOLIO_MEAN_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_PORTFOLIO_LAST_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_PRODUCT_TYPE_MEAN_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_PRODUCT_TYPE_LAST_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CHANNEL_TYPE_MEAN_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CHANNEL_TYPE_LAST_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour SELLERPLACE_AREA_MEAN_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour SELLERPLACE_AREA_MAX_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour SELLERPLACE_AREA_MIN_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_SELLER_INDUSTRY_MEAN_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_SELLER_INDUSTRY_LAST_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CNT_PAYMENT_SUM_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_YIELD_GROUP_MEAN_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_YIELD_GROUP_LAST_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour PRODUCT_COMBINATION_MEAN_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour PRODUCT_COMBINATION_LAST_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NFLAG_INSURED_ON_APPROVAL_SUM_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_DECLINED_MEAN_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_DECLINED_MAX_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_DECLINED_SUM_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_APPLICATION_RATIO_MEAN_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_APPLICATION_RATIO_MIN_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour INTEREST_DOWNPAYMENT_SUM_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour INTEREST_CREDIT_SUM_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour INTEREST_CREDIT_PRIVILEGED_SUM_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour APPLICATION_AMT_TO_DECISION_RATIO_MEAN_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour APPLICATION_AMT_TO_DECISION_RATIO_MIN_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_APPLICATION_TO_SELLERPLACE_AREA_MEAN_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_APPLICATION_TO_SELLERPLACE_AREA_MAX_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour ANNUITY_SUM_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour ANNUITY_GOODS_SUM_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_HOUR_PROCESS_START_MEAN_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_HOUR_PROCESS_START_SUM_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_NFLAG_LAST_APPL_DAY_MEAN_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_NFLAG_LAST_APPL_DAY_MAX_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_YIELD_GROUP_MEAN_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_YIELD_GROUP_SUM_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_YIELD_GROUP_MIN_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_INTEREST_SUM_LAST_5.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour MISSING_VALUES_TOTAL_PREV_SUM_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_CONTRACT_TYPE_MEAN_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_CONTRACT_TYPE_LAST_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_ANNUITY_SUM_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_APPLICATION_MEAN_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_APPLICATION_MAX_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_APPLICATION_SUM_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_MEAN_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_MAX_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_SUM_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_DOWN_PAYMENT_SUM_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_GOODS_PRICE_SUM_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour WEEKDAY_APPR_PROCESS_START_MEAN_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour WEEKDAY_APPR_PROCESS_START_MAX_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour WEEKDAY_APPR_PROCESS_START_MIN_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour HOUR_APPR_PROCESS_START_MEAN_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour HOUR_APPR_PROCESS_START_MAX_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour HOUR_APPR_PROCESS_START_MIN_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour FLAG_LAST_APPL_PER_CONTRACT_MEAN_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour FLAG_LAST_APPL_PER_CONTRACT_SUM_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NFLAG_LAST_APPL_IN_DAY_MEAN_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NFLAG_LAST_APPL_IN_DAY_SUM_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_CASH_LOAN_PURPOSE_MEAN_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_CASH_LOAN_PURPOSE_LAST_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_CONTRACT_STATUS_MEAN_FIRST_2.
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_CONTRACT_STATUS_MAX_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_CONTRACT_STATUS_LAST_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour DAYS_DECISION_MEAN_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour DAYS_DECISION_MAX_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour DAYS_DECISION_MIN_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_PAYMENT_TYPE_MEAN_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_PAYMENT_TYPE_LAST_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CODE_REJECT_REASON_MEAN_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CODE_REJECT_REASON_LAST_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_TYPE_SUITE_MEAN_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_TYPE_SUITE_LAST_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_CLIENT_TYPE_MEAN_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_CLIENT_TYPE_LAST_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_GOODS_CATEGORY_MEAN_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_GOODS_CATEGORY_LAST_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_PORTFOLIO_MEAN_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_PORTFOLIO_LAST_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_PRODUCT_TYPE_MEAN_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_PRODUCT_TYPE_LAST_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CHANNEL_TYPE_MEAN_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CHANNEL_TYPE_LAST_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour SELLERPLACE_AREA_MEAN_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour SELLERPLACE_AREA_MAX_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour SELLERPLACE_AREA_MIN_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_SELLER_INDUSTRY_MEAN_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_SELLER_INDUSTRY_LAST_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CNT_PAYMENT_SUM_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_YIELD_GROUP_MEAN_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_YIELD_GROUP_LAST_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour PRODUCT_COMBINATION_MEAN_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour PRODUCT_COMBINATION_LAST_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NFLAG_INSURED_ON_APPROVAL_SUM_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_DECLINED_MEAN_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_DECLINED_MAX_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_DECLINED_SUM_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_APPLICATION_RATIO_MEAN_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_APPLICATION_RATIO_MIN_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour INTEREST_DOWNPAYMENT_SUM_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour INTEREST_CREDIT_SUM_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour INTEREST_CREDIT_PRIVILEGED_SUM_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour APPLICATION_AMT_TO_DECISION_RATIO_MEAN_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour APPLICATION_AMT_TO_DECISION_RATIO_MIN_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_APPLICATION_TO_SELLERPLACE_AREA_MEAN_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_APPLICATION_TO_SELLERPLACE_AREA_MAX_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour ANNUITY_SUM_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour ANNUITY_GOODS_SUM_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_HOUR_PROCESS_START_MEAN_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_HOUR_PROCESS_START_SUM_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_NFLAG_LAST_APPL_DAY_MEAN_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_NFLAG_LAST_APPL_DAY_MAX_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_YIELD_GROUP_MEAN_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_YIELD_GROUP_SUM_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_YIELD_GROUP_MIN_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_INTEREST_SUM_FIRST_2.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour MISSING_VALUES_TOTAL_PREV_SUM_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_CONTRACT_TYPE_MEAN_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_CONTRACT_TYPE_LAST_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_ANNUITY_SUM_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_APPLICATION_MEAN_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_APPLICATION_MAX_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_APPLICATION_SUM_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_MEAN_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_MAX_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_SUM_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_DOWN_PAYMENT_SUM_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_GOODS_PRICE_SUM_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour WEEKDAY_APPR_PROCESS_START_MEAN_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour WEEKDAY_APPR_PROCESS_START_MAX_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour WEEKDAY_APPR_PROCESS_START_MIN_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour HOUR_APPR_PROCESS_START_MEAN_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour HOUR_APPR_PROCESS_START_MAX_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour HOUR_APPR_PROCESS_START_MIN_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour FLAG_LAST_APPL_PER_CONTRACT_MEAN_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour FLAG_LAST_APPL_PER_CONTRACT_SUM_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NFLAG_LAST_APPL_IN_DAY_MEAN_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NFLAG_LAST_APPL_IN_DAY_SUM_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_CASH_LOAN_PURPOSE_MEAN_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_CASH_LOAN_PURPOSE_LAST_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_CONTRACT_STATUS_MEAN_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_CONTRACT_STATUS_MAX_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_CONTRACT_STATUS_LAST_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour DAYS_DECISION_MEAN_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour DAYS_DECISION_MAX_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour DAYS_DECISION_MIN_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_PAYMENT_TYPE_MEAN_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_PAYMENT_TYPE_LAST_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CODE_REJECT_REASON_MEAN_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CODE_REJECT_REASON_LAST_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_TYPE_SUITE_MEAN_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_TYPE_SUITE_LAST_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_CLIENT_TYPE_MEAN_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_CLIENT_TYPE_LAST_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_GOODS_CATEGORY_MEAN_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_GOODS_CATEGORY_LAST_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_PORTFOLIO_MEAN_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_PORTFOLIO_LAST_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_PRODUCT_TYPE_MEAN_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_PRODUCT_TYPE_LAST_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CHANNEL_TYPE_MEAN_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour CHANNEL_TYPE_LAST_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour SELLERPLACE_AREA_MEAN_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour SELLERPLACE_AREA_MAX_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour SELLERPLACE_AREA_MIN_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_SELLER_INDUSTRY_MEAN_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_SELLER_INDUSTRY_LAST_ALL.
# Les conditions pour l'ANOVA ne sont pas remplies pour CNT_PAYMENT_SUM_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_YIELD_GROUP_MEAN_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NAME_YIELD_GROUP_LAST_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour PRODUCT_COMBINATION_MEAN_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour PRODUCT_COMBINATION_LAST_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour NFLAG_INSURED_ON_APPROVAL_SUM_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_DECLINED_MEAN_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_DECLINED_MAX_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_DECLINED_SUM_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_APPLICATION_RATIO_MEAN_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_APPLICATION_RATIO_MIN_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour INTEREST_DOWNPAYMENT_SUM_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour INTEREST_CREDIT_SUM_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour INTEREST_CREDIT_PRIVILEGED_SUM_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour APPLICATION_AMT_TO_DECISION_RATIO_MEAN_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour APPLICATION_AMT_TO_DECISION_RATIO_MIN_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_APPLICATION_TO_SELLERPLACE_AREA_MEAN_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_APPLICATION_TO_SELLERPLACE_AREA_MAX_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour ANNUITY_SUM_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour ANNUITY_GOODS_SUM_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_HOUR_PROCESS_START_MEAN_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_HOUR_PROCESS_START_SUM_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_NFLAG_LAST_APPL_DAY_MEAN_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_NFLAG_LAST_APPL_DAY_MAX_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_YIELD_GROUP_MEAN_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_YIELD_GROUP_SUM_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_CREDIT_YIELD_GROUP_MIN_ALL.
#
#
# Les conditions pour l'ANOVA ne sont pas remplies pour AMT_INTEREST_SUM_ALL.

# %%
def check_conditions(group1, group2, numerical_column):
    # Vérifier l'homogénéité des variances
    levene_stat, levene_pvalue = levene(group1[numerical_column], group2[numerical_column])
    
    # Vérifier la normalité des résidus
    shapiro_stat_group1, shapiro_pvalue_group1 = shapiro(group1[numerical_column])
    shapiro_stat_group2, shapiro_pvalue_group2 = shapiro(group2[numerical_column])
    
    return (levene_pvalue > 0.05) and (shapiro_pvalue_group1 > 0.05) and (shapiro_pvalue_group2 > 0.05)

# Appliquer le test de Kruskal-Wallis pour chaque caractéristique numérique
for column in numerical_columns:
    if check_conditions(group1, group2, column):
        stat, p = kruskal(group1[column], group2[column])
        print(f"Relation entre {column} et la TARGET :")
        print(f"Statistique Kruskal-Wallis : {stat}")
        print(f"p-value : {p}")
        print("\n")
    else:
        print(f"Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour {column}.")
        print("\n")
# Out:
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour SK_ID_CURR.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CNT_CHILDREN.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_INCOME_TOTAL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_ANNUITY.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_GOODS_PRICE.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour REGION_POPULATION_RELATIVE.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour DAYS_BIRTH.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour DAYS_EMPLOYED.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour DAYS_REGISTRATION.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour DAYS_ID_PUBLISH.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour FLAG_MOBIL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour FLAG_EMP_PHONE.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour FLAG_WORK_PHONE.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour FLAG_CONT_MOBILE.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour FLAG_PHONE.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour FLAG_EMAIL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CNT_FAM_MEMBERS.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour REGION_RATING_CLIENT.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour REGION_RATING_CLIENT_W_CITY.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour HOUR_APPR_PROCESS_START.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour REG_REGION_NOT_LIVE_REGION.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour REG_REGION_NOT_WORK_REGION.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour LIVE_REGION_NOT_WORK_REGION.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour REG_CITY_NOT_LIVE_CITY.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour REG_CITY_NOT_WORK_CITY.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour LIVE_CITY_NOT_WORK_CITY.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour EXT_SOURCE_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour EXT_SOURCE_3.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour OBS_30_CNT_SOCIAL_CIRCLE.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour DEF_30_CNT_SOCIAL_CIRCLE.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour OBS_60_CNT_SOCIAL_CIRCLE.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour DEF_60_CNT_SOCIAL_CIRCLE.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour DAYS_LAST_PHONE_CHANGE.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour FLAG_DOCUMENT_3.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour FLAG_DOCUMENT_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour FLAG_DOCUMENT_6.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour FLAG_DOCUMENT_7.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour FLAG_DOCUMENT_8.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour FLAG_DOCUMENT_9.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour FLAG_DOCUMENT_11.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour FLAG_DOCUMENT_13.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour FLAG_DOCUMENT_14.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour FLAG_DOCUMENT_15.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour FLAG_DOCUMENT_16.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour FLAG_DOCUMENT_17.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour FLAG_DOCUMENT_18.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour FLAG_DOCUMENT_19.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour FLAG_DOCUMENT_21.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_REQ_CREDIT_BUREAU_HOUR.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_REQ_CREDIT_BUREAU_DAY.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_REQ_CREDIT_BUREAU_WEEK.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_REQ_CREDIT_BUREAU_MON.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_REQ_CREDIT_BUREAU_QRT.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_REQ_CREDIT_BUREAU_YEAR.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour MISSING_VALS_TOTAL_APP.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CREDIT_INCOME_RATIO.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CREDIT_ANNUITY_RATIO.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour ANNUITY_INCOME_RATIO.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour INCOME_ANNUITY_DIFF.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CREDIT_GOODS_RATIO.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CREDIT_GOODS_DIFF.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour GOODS_INCOME_RATIO.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour INCOME_EXT_RATIO.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CREDIT_EXT_RATIO.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AGE_EMPLOYED_DIFF.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour EMPLOYED_TO_AGE_RATIO.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour FLAG_CONTACTS_SUM.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour HOUR_PROCESS_CREDIT_MUL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CNT_NON_CHILDREN.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CHILDREN_INCOME_RATIO.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour PER_CAPITA_INCOME.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour REGIONS_RATING_INCOME_MUL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour REGION_RATING_MAX.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour REGION_RATING_MEAN.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour REGION_RATING_MUL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour FLAG_REGIONS.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour OBS_30_60_SUM.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour DEF_30_60_SUM.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour OBS_DEF_30_MUL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour OBS_DEF_60_MUL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour SUM_OBS_DEF_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour OBS_30_CREDIT_RATIO.
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour OBS_60_CREDIT_RATIO.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour DEF_30_CREDIT_RATIO.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour DEF_60_CREDIT_RATIO.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour SUM_FLAGS_DOCUMENTS.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour DAYS_DETAILS_CHANGE_MUL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour DAYS_DETAILS_CHANGE_SUM.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_ENQ_SUM.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour ENQ_CREDIT_RATIO.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour DAYS_CREDIT_MEAN_OVERALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CREDIT_DAY_OVERDUE_MEAN_OVERALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CNT_CREDIT_PROLONG_MEAN_OVERALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_SUM_MEAN_OVERALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_SUM_DEBT_MEAN_OVERALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_SUM_OVERDUE_MEAN_OVERALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour FLAG_OVERDUE_RECENT_MEAN_OVERALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CURRENT_DEBT_TO_CREDIT_RATIO_MEAN_OVERALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CURRENT_CREDIT_DEBT_DIFF_MEAN_OVERALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CURRENCY_currency 1_MEAN_OVERALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CURRENCY_currency 2_MEAN_OVERALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CURRENCY_currency 3_MEAN_OVERALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CURRENCY_currency 4_MEAN_OVERALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CREDIT_ACTIVE_Active_MEAN_OVERALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CREDIT_ACTIVE_Bad debt_MEAN_OVERALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CREDIT_ACTIVE_Closed_MEAN_OVERALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CREDIT_ACTIVE_Sold_MEAN_OVERALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CREDIT_TYPE_Another type of loan_MEAN_OVERALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CREDIT_TYPE_Car loan_MEAN_OVERALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CREDIT_TYPE_Cash loan (non-earmarked)_MEAN_OVERALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CREDIT_TYPE_Consumer credit_MEAN_OVERALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CREDIT_TYPE_Credit card_MEAN_OVERALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CREDIT_TYPE_Interbank credit_MEAN_OVERALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CREDIT_TYPE_Loan for business development_MEAN_OVERALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CREDIT_TYPE_Loan for purchase of shares (margin lending)_MEAN_OVERALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CREDIT_TYPE_Loan for the purchase of equipment_MEAN_OVERALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CREDIT_TYPE_Loan for working capital replenishment_MEAN_OVERALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CREDIT_TYPE_Microloan_MEAN_OVERALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CREDIT_TYPE_Mobile operator loan_MEAN_OVERALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CREDIT_TYPE_Mortgage_MEAN_OVERALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CREDIT_TYPE_Real estate loan_MEAN_OVERALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CREDIT_TYPE_Unknown type of loan_MEAN_OVERALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour MISSING_VALUES_TOTAL_PREV_SUM_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_CONTRACT_TYPE_MEAN_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_CONTRACT_TYPE_LAST_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_ANNUITY_SUM_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_APPLICATION_MEAN_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_APPLICATION_MAX_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_APPLICATION_SUM_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_MEAN_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_MAX_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_SUM_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_DOWN_PAYMENT_SUM_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_GOODS_PRICE_SUM_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour WEEKDAY_APPR_PROCESS_START_MEAN_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour WEEKDAY_APPR_PROCESS_START_MAX_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour WEEKDAY_APPR_PROCESS_START_MIN_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour HOUR_APPR_PROCESS_START_MEAN_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour HOUR_APPR_PROCESS_START_MAX_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour HOUR_APPR_PROCESS_START_MIN_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour FLAG_LAST_APPL_PER_CONTRACT_MEAN_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour FLAG_LAST_APPL_PER_CONTRACT_SUM_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NFLAG_LAST_APPL_IN_DAY_MEAN_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NFLAG_LAST_APPL_IN_DAY_SUM_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_CASH_LOAN_PURPOSE_MEAN_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_CASH_LOAN_PURPOSE_LAST_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_CONTRACT_STATUS_MEAN_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_CONTRACT_STATUS_MAX_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_CONTRACT_STATUS_LAST_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour DAYS_DECISION_MEAN_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour DAYS_DECISION_MAX_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour DAYS_DECISION_MIN_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_PAYMENT_TYPE_MEAN_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_PAYMENT_TYPE_LAST_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CODE_REJECT_REASON_MEAN_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CODE_REJECT_REASON_LAST_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_TYPE_SUITE_MEAN_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_TYPE_SUITE_LAST_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_CLIENT_TYPE_MEAN_LAST_5.
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_CLIENT_TYPE_LAST_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_GOODS_CATEGORY_MEAN_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_GOODS_CATEGORY_LAST_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_PORTFOLIO_MEAN_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_PORTFOLIO_LAST_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_PRODUCT_TYPE_MEAN_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_PRODUCT_TYPE_LAST_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CHANNEL_TYPE_MEAN_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CHANNEL_TYPE_LAST_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour SELLERPLACE_AREA_MEAN_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour SELLERPLACE_AREA_MAX_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour SELLERPLACE_AREA_MIN_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_SELLER_INDUSTRY_MEAN_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_SELLER_INDUSTRY_LAST_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CNT_PAYMENT_SUM_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_YIELD_GROUP_MEAN_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_YIELD_GROUP_LAST_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour PRODUCT_COMBINATION_MEAN_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour PRODUCT_COMBINATION_LAST_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NFLAG_INSURED_ON_APPROVAL_SUM_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_DECLINED_MEAN_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_DECLINED_MAX_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_DECLINED_SUM_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_APPLICATION_RATIO_MEAN_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_APPLICATION_RATIO_MIN_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour INTEREST_DOWNPAYMENT_SUM_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour INTEREST_CREDIT_SUM_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour INTEREST_CREDIT_PRIVILEGED_SUM_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour APPLICATION_AMT_TO_DECISION_RATIO_MEAN_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour APPLICATION_AMT_TO_DECISION_RATIO_MIN_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_APPLICATION_TO_SELLERPLACE_AREA_MEAN_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_APPLICATION_TO_SELLERPLACE_AREA_MAX_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour ANNUITY_SUM_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour ANNUITY_GOODS_SUM_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_HOUR_PROCESS_START_MEAN_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_HOUR_PROCESS_START_SUM_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_NFLAG_LAST_APPL_DAY_MEAN_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_NFLAG_LAST_APPL_DAY_MAX_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_YIELD_GROUP_MEAN_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_YIELD_GROUP_SUM_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_YIELD_GROUP_MIN_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_INTEREST_SUM_LAST_5.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour MISSING_VALUES_TOTAL_PREV_SUM_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_CONTRACT_TYPE_MEAN_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_CONTRACT_TYPE_LAST_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_ANNUITY_SUM_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_APPLICATION_MEAN_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_APPLICATION_MAX_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_APPLICATION_SUM_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_MEAN_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_MAX_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_SUM_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_DOWN_PAYMENT_SUM_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_GOODS_PRICE_SUM_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour WEEKDAY_APPR_PROCESS_START_MEAN_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour WEEKDAY_APPR_PROCESS_START_MAX_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour WEEKDAY_APPR_PROCESS_START_MIN_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour HOUR_APPR_PROCESS_START_MEAN_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour HOUR_APPR_PROCESS_START_MAX_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour HOUR_APPR_PROCESS_START_MIN_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour FLAG_LAST_APPL_PER_CONTRACT_MEAN_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour FLAG_LAST_APPL_PER_CONTRACT_SUM_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NFLAG_LAST_APPL_IN_DAY_MEAN_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NFLAG_LAST_APPL_IN_DAY_SUM_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_CASH_LOAN_PURPOSE_MEAN_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_CASH_LOAN_PURPOSE_LAST_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_CONTRACT_STATUS_MEAN_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_CONTRACT_STATUS_MAX_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_CONTRACT_STATUS_LAST_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour DAYS_DECISION_MEAN_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour DAYS_DECISION_MAX_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour DAYS_DECISION_MIN_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_PAYMENT_TYPE_MEAN_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_PAYMENT_TYPE_LAST_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CODE_REJECT_REASON_MEAN_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CODE_REJECT_REASON_LAST_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_TYPE_SUITE_MEAN_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_TYPE_SUITE_LAST_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_CLIENT_TYPE_MEAN_FIRST_2.
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_CLIENT_TYPE_LAST_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_GOODS_CATEGORY_MEAN_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_GOODS_CATEGORY_LAST_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_PORTFOLIO_MEAN_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_PORTFOLIO_LAST_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_PRODUCT_TYPE_MEAN_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_PRODUCT_TYPE_LAST_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CHANNEL_TYPE_MEAN_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CHANNEL_TYPE_LAST_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour SELLERPLACE_AREA_MEAN_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour SELLERPLACE_AREA_MAX_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour SELLERPLACE_AREA_MIN_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_SELLER_INDUSTRY_MEAN_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_SELLER_INDUSTRY_LAST_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CNT_PAYMENT_SUM_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_YIELD_GROUP_MEAN_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_YIELD_GROUP_LAST_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour PRODUCT_COMBINATION_MEAN_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour PRODUCT_COMBINATION_LAST_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NFLAG_INSURED_ON_APPROVAL_SUM_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_DECLINED_MEAN_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_DECLINED_MAX_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_DECLINED_SUM_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_APPLICATION_RATIO_MEAN_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_APPLICATION_RATIO_MIN_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour INTEREST_DOWNPAYMENT_SUM_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour INTEREST_CREDIT_SUM_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour INTEREST_CREDIT_PRIVILEGED_SUM_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour APPLICATION_AMT_TO_DECISION_RATIO_MEAN_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour APPLICATION_AMT_TO_DECISION_RATIO_MIN_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_APPLICATION_TO_SELLERPLACE_AREA_MEAN_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_APPLICATION_TO_SELLERPLACE_AREA_MAX_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour ANNUITY_SUM_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour ANNUITY_GOODS_SUM_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_HOUR_PROCESS_START_MEAN_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_HOUR_PROCESS_START_SUM_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_NFLAG_LAST_APPL_DAY_MEAN_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_NFLAG_LAST_APPL_DAY_MAX_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_YIELD_GROUP_MEAN_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_YIELD_GROUP_SUM_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_YIELD_GROUP_MIN_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_INTEREST_SUM_FIRST_2.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour MISSING_VALUES_TOTAL_PREV_SUM_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_CONTRACT_TYPE_MEAN_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_CONTRACT_TYPE_LAST_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_ANNUITY_SUM_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_APPLICATION_MEAN_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_APPLICATION_MAX_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_APPLICATION_SUM_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_MEAN_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_MAX_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_SUM_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_DOWN_PAYMENT_SUM_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_GOODS_PRICE_SUM_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour WEEKDAY_APPR_PROCESS_START_MEAN_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour WEEKDAY_APPR_PROCESS_START_MAX_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour WEEKDAY_APPR_PROCESS_START_MIN_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour HOUR_APPR_PROCESS_START_MEAN_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour HOUR_APPR_PROCESS_START_MAX_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour HOUR_APPR_PROCESS_START_MIN_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour FLAG_LAST_APPL_PER_CONTRACT_MEAN_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour FLAG_LAST_APPL_PER_CONTRACT_SUM_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NFLAG_LAST_APPL_IN_DAY_MEAN_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NFLAG_LAST_APPL_IN_DAY_SUM_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_CASH_LOAN_PURPOSE_MEAN_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_CASH_LOAN_PURPOSE_LAST_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_CONTRACT_STATUS_MEAN_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_CONTRACT_STATUS_MAX_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_CONTRACT_STATUS_LAST_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour DAYS_DECISION_MEAN_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour DAYS_DECISION_MAX_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour DAYS_DECISION_MIN_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_PAYMENT_TYPE_MEAN_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_PAYMENT_TYPE_LAST_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CODE_REJECT_REASON_MEAN_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CODE_REJECT_REASON_LAST_ALL.
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_TYPE_SUITE_MEAN_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_TYPE_SUITE_LAST_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_CLIENT_TYPE_MEAN_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_CLIENT_TYPE_LAST_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_GOODS_CATEGORY_MEAN_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_GOODS_CATEGORY_LAST_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_PORTFOLIO_MEAN_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_PORTFOLIO_LAST_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_PRODUCT_TYPE_MEAN_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_PRODUCT_TYPE_LAST_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CHANNEL_TYPE_MEAN_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CHANNEL_TYPE_LAST_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour SELLERPLACE_AREA_MEAN_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour SELLERPLACE_AREA_MAX_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour SELLERPLACE_AREA_MIN_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_SELLER_INDUSTRY_MEAN_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_SELLER_INDUSTRY_LAST_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour CNT_PAYMENT_SUM_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_YIELD_GROUP_MEAN_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NAME_YIELD_GROUP_LAST_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour PRODUCT_COMBINATION_MEAN_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour PRODUCT_COMBINATION_LAST_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour NFLAG_INSURED_ON_APPROVAL_SUM_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_DECLINED_MEAN_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_DECLINED_MAX_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_DECLINED_SUM_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_APPLICATION_RATIO_MEAN_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_APPLICATION_RATIO_MIN_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour INTEREST_DOWNPAYMENT_SUM_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour INTEREST_CREDIT_SUM_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour INTEREST_CREDIT_PRIVILEGED_SUM_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour APPLICATION_AMT_TO_DECISION_RATIO_MEAN_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour APPLICATION_AMT_TO_DECISION_RATIO_MIN_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_APPLICATION_TO_SELLERPLACE_AREA_MEAN_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_APPLICATION_TO_SELLERPLACE_AREA_MAX_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour ANNUITY_SUM_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour ANNUITY_GOODS_SUM_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_HOUR_PROCESS_START_MEAN_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_HOUR_PROCESS_START_SUM_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_NFLAG_LAST_APPL_DAY_MEAN_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_NFLAG_LAST_APPL_DAY_MAX_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_YIELD_GROUP_MEAN_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_YIELD_GROUP_SUM_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_CREDIT_YIELD_GROUP_MIN_ALL.
#
#
# Les conditions pour effectuer le test de Kruskal-Wallis ne sont pas remplies pour AMT_INTEREST_SUM_ALL.

# %%
def check_conditions(group1, group2, numerical_column):
    # Vérifier la normalité des résidus
    shapiro_stat_group1, shapiro_pvalue_group1 = shapiro(group1[numerical_column])
    shapiro_stat_group2, shapiro_pvalue_group2 = shapiro(group2[numerical_column])
    
    return (shapiro_pvalue_group1 > 0.05) and (shapiro_pvalue_group2 > 0.05)

# Appliquer le test de Mann-Whitney U pour chaque caractéristique numérique
for column in numerical_columns:
    if check_conditions(group1, group2, column):
        stat, p = mannwhitneyu(group1[column], group2[column])
        print(f"Relation entre {column} et la TARGET :")
        print(f"Statistique du test de Mann-Whitney U : {stat}")
        print(f"p-value : {p}")
        print("\n")
    else:
        print(f"Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour {column}.")
        print("\n")
# Out:
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour SK_ID_CURR.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour CNT_CHILDREN.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour AMT_INCOME_TOTAL.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour AMT_CREDIT.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour AMT_ANNUITY.
#
#
# Relation entre AMT_GOODS_PRICE et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour REGION_POPULATION_RELATIVE.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour DAYS_BIRTH.
#
#
# Relation entre DAYS_EMPLOYED et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour DAYS_REGISTRATION.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour DAYS_ID_PUBLISH.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour FLAG_MOBIL.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour FLAG_EMP_PHONE.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour FLAG_WORK_PHONE.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour FLAG_CONT_MOBILE.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour FLAG_PHONE.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour FLAG_EMAIL.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour CNT_FAM_MEMBERS.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour REGION_RATING_CLIENT.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour REGION_RATING_CLIENT_W_CITY.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour HOUR_APPR_PROCESS_START.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour REG_REGION_NOT_LIVE_REGION.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour REG_REGION_NOT_WORK_REGION.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour LIVE_REGION_NOT_WORK_REGION.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour REG_CITY_NOT_LIVE_CITY.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour REG_CITY_NOT_WORK_CITY.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour LIVE_CITY_NOT_WORK_CITY.
#
#
# Relation entre EXT_SOURCE_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre EXT_SOURCE_3 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre OBS_30_CNT_SOCIAL_CIRCLE et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre DEF_30_CNT_SOCIAL_CIRCLE et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre OBS_60_CNT_SOCIAL_CIRCLE et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre DEF_60_CNT_SOCIAL_CIRCLE et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour DAYS_LAST_PHONE_CHANGE.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour FLAG_DOCUMENT_3.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour FLAG_DOCUMENT_5.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour FLAG_DOCUMENT_6.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour FLAG_DOCUMENT_7.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour FLAG_DOCUMENT_8.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour FLAG_DOCUMENT_9.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour FLAG_DOCUMENT_11.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour FLAG_DOCUMENT_13.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour FLAG_DOCUMENT_14.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour FLAG_DOCUMENT_15.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour FLAG_DOCUMENT_16.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour FLAG_DOCUMENT_17.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour FLAG_DOCUMENT_18.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour FLAG_DOCUMENT_19.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour FLAG_DOCUMENT_21.
#
#
# Relation entre AMT_REQ_CREDIT_BUREAU_HOUR et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_REQ_CREDIT_BUREAU_DAY et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_REQ_CREDIT_BUREAU_WEEK et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_REQ_CREDIT_BUREAU_MON et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_REQ_CREDIT_BUREAU_QRT et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_REQ_CREDIT_BUREAU_YEAR et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour MISSING_VALS_TOTAL_APP.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour CREDIT_INCOME_RATIO.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour CREDIT_ANNUITY_RATIO.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour ANNUITY_INCOME_RATIO.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour INCOME_ANNUITY_DIFF.
#
#
# Relation entre CREDIT_GOODS_RATIO et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CREDIT_GOODS_DIFF et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre GOODS_INCOME_RATIO et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre INCOME_EXT_RATIO et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CREDIT_EXT_RATIO et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AGE_EMPLOYED_DIFF et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre EMPLOYED_TO_AGE_RATIO et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour FLAG_CONTACTS_SUM.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour HOUR_PROCESS_CREDIT_MUL.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour CNT_NON_CHILDREN.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour CHILDREN_INCOME_RATIO.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour PER_CAPITA_INCOME.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour REGIONS_RATING_INCOME_MUL.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour REGION_RATING_MAX.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour REGION_RATING_MEAN.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour REGION_RATING_MUL.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour FLAG_REGIONS.
#
#
# Relation entre OBS_30_60_SUM et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre DEF_30_60_SUM et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre OBS_DEF_30_MUL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre OBS_DEF_60_MUL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre SUM_OBS_DEF_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre OBS_30_CREDIT_RATIO et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre OBS_60_CREDIT_RATIO et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre DEF_30_CREDIT_RATIO et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre DEF_60_CREDIT_RATIO et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour SUM_FLAGS_DOCUMENTS.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour DAYS_DETAILS_CHANGE_MUL.
#
#
# Les conditions pour effectuer le test de Mann-Whitney U ne sont pas remplies pour DAYS_DETAILS_CHANGE_SUM.
#
#
# Relation entre AMT_ENQ_SUM et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre ENQ_CREDIT_RATIO et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre DAYS_CREDIT_MEAN_OVERALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CREDIT_DAY_OVERDUE_MEAN_OVERALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CNT_CREDIT_PROLONG_MEAN_OVERALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_SUM_MEAN_OVERALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
# Relation entre AMT_CREDIT_SUM_DEBT_MEAN_OVERALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_SUM_OVERDUE_MEAN_OVERALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre FLAG_OVERDUE_RECENT_MEAN_OVERALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CURRENT_DEBT_TO_CREDIT_RATIO_MEAN_OVERALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CURRENT_CREDIT_DEBT_DIFF_MEAN_OVERALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CURRENCY_currency 1_MEAN_OVERALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CURRENCY_currency 2_MEAN_OVERALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CURRENCY_currency 3_MEAN_OVERALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CURRENCY_currency 4_MEAN_OVERALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CREDIT_ACTIVE_Active_MEAN_OVERALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CREDIT_ACTIVE_Bad debt_MEAN_OVERALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CREDIT_ACTIVE_Closed_MEAN_OVERALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CREDIT_ACTIVE_Sold_MEAN_OVERALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CREDIT_TYPE_Another type of loan_MEAN_OVERALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CREDIT_TYPE_Car loan_MEAN_OVERALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CREDIT_TYPE_Cash loan (non-earmarked)_MEAN_OVERALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CREDIT_TYPE_Consumer credit_MEAN_OVERALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CREDIT_TYPE_Credit card_MEAN_OVERALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CREDIT_TYPE_Interbank credit_MEAN_OVERALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CREDIT_TYPE_Loan for business development_MEAN_OVERALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CREDIT_TYPE_Loan for purchase of shares (margin lending)_MEAN_OVERALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CREDIT_TYPE_Loan for the purchase of equipment_MEAN_OVERALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CREDIT_TYPE_Loan for working capital replenishment_MEAN_OVERALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CREDIT_TYPE_Microloan_MEAN_OVERALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CREDIT_TYPE_Mobile operator loan_MEAN_OVERALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CREDIT_TYPE_Mortgage_MEAN_OVERALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CREDIT_TYPE_Real estate loan_MEAN_OVERALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CREDIT_TYPE_Unknown type of loan_MEAN_OVERALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre MISSING_VALUES_TOTAL_PREV_SUM_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_CONTRACT_TYPE_MEAN_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_CONTRACT_TYPE_LAST_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_ANNUITY_SUM_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_APPLICATION_MEAN_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_APPLICATION_MAX_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_APPLICATION_SUM_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_MEAN_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_MAX_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_SUM_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_DOWN_PAYMENT_SUM_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_GOODS_PRICE_SUM_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre WEEKDAY_APPR_PROCESS_START_MEAN_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre WEEKDAY_APPR_PROCESS_START_MAX_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre WEEKDAY_APPR_PROCESS_START_MIN_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre HOUR_APPR_PROCESS_START_MEAN_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre HOUR_APPR_PROCESS_START_MAX_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre HOUR_APPR_PROCESS_START_MIN_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre FLAG_LAST_APPL_PER_CONTRACT_MEAN_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre FLAG_LAST_APPL_PER_CONTRACT_SUM_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NFLAG_LAST_APPL_IN_DAY_MEAN_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NFLAG_LAST_APPL_IN_DAY_SUM_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_CASH_LOAN_PURPOSE_MEAN_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_CASH_LOAN_PURPOSE_LAST_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_CONTRACT_STATUS_MEAN_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_CONTRACT_STATUS_MAX_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_CONTRACT_STATUS_LAST_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre DAYS_DECISION_MEAN_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre DAYS_DECISION_MAX_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre DAYS_DECISION_MIN_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_PAYMENT_TYPE_MEAN_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_PAYMENT_TYPE_LAST_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CODE_REJECT_REASON_MEAN_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CODE_REJECT_REASON_LAST_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_TYPE_SUITE_MEAN_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_TYPE_SUITE_LAST_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_CLIENT_TYPE_MEAN_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_CLIENT_TYPE_LAST_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_GOODS_CATEGORY_MEAN_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_GOODS_CATEGORY_LAST_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_PORTFOLIO_MEAN_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_PORTFOLIO_LAST_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_PRODUCT_TYPE_MEAN_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_PRODUCT_TYPE_LAST_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CHANNEL_TYPE_MEAN_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
# Relation entre CHANNEL_TYPE_LAST_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre SELLERPLACE_AREA_MEAN_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre SELLERPLACE_AREA_MAX_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre SELLERPLACE_AREA_MIN_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_SELLER_INDUSTRY_MEAN_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_SELLER_INDUSTRY_LAST_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CNT_PAYMENT_SUM_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_YIELD_GROUP_MEAN_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_YIELD_GROUP_LAST_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre PRODUCT_COMBINATION_MEAN_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre PRODUCT_COMBINATION_LAST_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NFLAG_INSURED_ON_APPROVAL_SUM_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_DECLINED_MEAN_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_DECLINED_MAX_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_DECLINED_SUM_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_APPLICATION_RATIO_MEAN_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_APPLICATION_RATIO_MIN_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre INTEREST_DOWNPAYMENT_SUM_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre INTEREST_CREDIT_SUM_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre INTEREST_CREDIT_PRIVILEGED_SUM_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre APPLICATION_AMT_TO_DECISION_RATIO_MEAN_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre APPLICATION_AMT_TO_DECISION_RATIO_MIN_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_APPLICATION_TO_SELLERPLACE_AREA_MEAN_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_APPLICATION_TO_SELLERPLACE_AREA_MAX_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre ANNUITY_SUM_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre ANNUITY_GOODS_SUM_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_HOUR_PROCESS_START_MEAN_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_HOUR_PROCESS_START_SUM_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_NFLAG_LAST_APPL_DAY_MEAN_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_NFLAG_LAST_APPL_DAY_MAX_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_YIELD_GROUP_MEAN_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_YIELD_GROUP_SUM_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_YIELD_GROUP_MIN_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_INTEREST_SUM_LAST_5 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre MISSING_VALUES_TOTAL_PREV_SUM_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_CONTRACT_TYPE_MEAN_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_CONTRACT_TYPE_LAST_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_ANNUITY_SUM_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_APPLICATION_MEAN_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_APPLICATION_MAX_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_APPLICATION_SUM_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_MEAN_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_MAX_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_SUM_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_DOWN_PAYMENT_SUM_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_GOODS_PRICE_SUM_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre WEEKDAY_APPR_PROCESS_START_MEAN_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre WEEKDAY_APPR_PROCESS_START_MAX_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre WEEKDAY_APPR_PROCESS_START_MIN_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre HOUR_APPR_PROCESS_START_MEAN_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre HOUR_APPR_PROCESS_START_MAX_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre HOUR_APPR_PROCESS_START_MIN_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre FLAG_LAST_APPL_PER_CONTRACT_MEAN_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre FLAG_LAST_APPL_PER_CONTRACT_SUM_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NFLAG_LAST_APPL_IN_DAY_MEAN_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NFLAG_LAST_APPL_IN_DAY_SUM_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_CASH_LOAN_PURPOSE_MEAN_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_CASH_LOAN_PURPOSE_LAST_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_CONTRACT_STATUS_MEAN_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_CONTRACT_STATUS_MAX_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_CONTRACT_STATUS_LAST_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre DAYS_DECISION_MEAN_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre DAYS_DECISION_MAX_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre DAYS_DECISION_MIN_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_PAYMENT_TYPE_MEAN_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_PAYMENT_TYPE_LAST_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CODE_REJECT_REASON_MEAN_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CODE_REJECT_REASON_LAST_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_TYPE_SUITE_MEAN_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_TYPE_SUITE_LAST_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
# Relation entre NAME_CLIENT_TYPE_MEAN_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_CLIENT_TYPE_LAST_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_GOODS_CATEGORY_MEAN_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_GOODS_CATEGORY_LAST_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_PORTFOLIO_MEAN_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_PORTFOLIO_LAST_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_PRODUCT_TYPE_MEAN_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_PRODUCT_TYPE_LAST_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CHANNEL_TYPE_MEAN_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CHANNEL_TYPE_LAST_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre SELLERPLACE_AREA_MEAN_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre SELLERPLACE_AREA_MAX_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre SELLERPLACE_AREA_MIN_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_SELLER_INDUSTRY_MEAN_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_SELLER_INDUSTRY_LAST_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CNT_PAYMENT_SUM_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_YIELD_GROUP_MEAN_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_YIELD_GROUP_LAST_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre PRODUCT_COMBINATION_MEAN_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre PRODUCT_COMBINATION_LAST_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NFLAG_INSURED_ON_APPROVAL_SUM_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_DECLINED_MEAN_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_DECLINED_MAX_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_DECLINED_SUM_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_APPLICATION_RATIO_MEAN_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_APPLICATION_RATIO_MIN_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre INTEREST_DOWNPAYMENT_SUM_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre INTEREST_CREDIT_SUM_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre INTEREST_CREDIT_PRIVILEGED_SUM_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre APPLICATION_AMT_TO_DECISION_RATIO_MEAN_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre APPLICATION_AMT_TO_DECISION_RATIO_MIN_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_APPLICATION_TO_SELLERPLACE_AREA_MEAN_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_APPLICATION_TO_SELLERPLACE_AREA_MAX_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre ANNUITY_SUM_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre ANNUITY_GOODS_SUM_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_HOUR_PROCESS_START_MEAN_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_HOUR_PROCESS_START_SUM_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_NFLAG_LAST_APPL_DAY_MEAN_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_NFLAG_LAST_APPL_DAY_MAX_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_YIELD_GROUP_MEAN_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_YIELD_GROUP_SUM_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_YIELD_GROUP_MIN_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_INTEREST_SUM_FIRST_2 et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre MISSING_VALUES_TOTAL_PREV_SUM_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_CONTRACT_TYPE_MEAN_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_CONTRACT_TYPE_LAST_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_ANNUITY_SUM_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_APPLICATION_MEAN_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_APPLICATION_MAX_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_APPLICATION_SUM_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_MEAN_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_MAX_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_SUM_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_DOWN_PAYMENT_SUM_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_GOODS_PRICE_SUM_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre WEEKDAY_APPR_PROCESS_START_MEAN_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre WEEKDAY_APPR_PROCESS_START_MAX_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre WEEKDAY_APPR_PROCESS_START_MIN_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre HOUR_APPR_PROCESS_START_MEAN_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre HOUR_APPR_PROCESS_START_MAX_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre HOUR_APPR_PROCESS_START_MIN_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre FLAG_LAST_APPL_PER_CONTRACT_MEAN_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre FLAG_LAST_APPL_PER_CONTRACT_SUM_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NFLAG_LAST_APPL_IN_DAY_MEAN_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NFLAG_LAST_APPL_IN_DAY_SUM_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_CASH_LOAN_PURPOSE_MEAN_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_CASH_LOAN_PURPOSE_LAST_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_CONTRACT_STATUS_MEAN_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_CONTRACT_STATUS_MAX_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_CONTRACT_STATUS_LAST_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
# Relation entre DAYS_DECISION_MEAN_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre DAYS_DECISION_MAX_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre DAYS_DECISION_MIN_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_PAYMENT_TYPE_MEAN_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_PAYMENT_TYPE_LAST_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CODE_REJECT_REASON_MEAN_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CODE_REJECT_REASON_LAST_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_TYPE_SUITE_MEAN_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_TYPE_SUITE_LAST_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_CLIENT_TYPE_MEAN_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_CLIENT_TYPE_LAST_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_GOODS_CATEGORY_MEAN_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_GOODS_CATEGORY_LAST_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_PORTFOLIO_MEAN_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_PORTFOLIO_LAST_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_PRODUCT_TYPE_MEAN_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_PRODUCT_TYPE_LAST_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CHANNEL_TYPE_MEAN_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CHANNEL_TYPE_LAST_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre SELLERPLACE_AREA_MEAN_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre SELLERPLACE_AREA_MAX_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre SELLERPLACE_AREA_MIN_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_SELLER_INDUSTRY_MEAN_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_SELLER_INDUSTRY_LAST_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre CNT_PAYMENT_SUM_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_YIELD_GROUP_MEAN_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NAME_YIELD_GROUP_LAST_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre PRODUCT_COMBINATION_MEAN_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre PRODUCT_COMBINATION_LAST_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre NFLAG_INSURED_ON_APPROVAL_SUM_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_DECLINED_MEAN_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_DECLINED_MAX_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_DECLINED_SUM_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_APPLICATION_RATIO_MEAN_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_APPLICATION_RATIO_MIN_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre INTEREST_DOWNPAYMENT_SUM_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre INTEREST_CREDIT_SUM_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre INTEREST_CREDIT_PRIVILEGED_SUM_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre APPLICATION_AMT_TO_DECISION_RATIO_MEAN_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre APPLICATION_AMT_TO_DECISION_RATIO_MIN_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_APPLICATION_TO_SELLERPLACE_AREA_MEAN_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_APPLICATION_TO_SELLERPLACE_AREA_MAX_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre ANNUITY_SUM_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre ANNUITY_GOODS_SUM_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_HOUR_PROCESS_START_MEAN_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_HOUR_PROCESS_START_SUM_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_NFLAG_LAST_APPL_DAY_MEAN_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_NFLAG_LAST_APPL_DAY_MAX_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_YIELD_GROUP_MEAN_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_YIELD_GROUP_SUM_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_YIELD_GROUP_MIN_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan
#
#
# Relation entre AMT_INTEREST_SUM_ALL et la TARGET :
# Statistique du test de Mann-Whitney U : nan
# p-value : nan

# %%
def check_conditions(group1, group2, numerical_column):
    # Vérifier la normalité des résidus
    shapiro_stat_group1, shapiro_pvalue_group1 = shapiro(group1[numerical_column])
    shapiro_stat_group2, shapiro_pvalue_group2 = shapiro(group2[numerical_column])
    
    return (shapiro_pvalue_group1 > 0.05) and (shapiro_pvalue_group2 > 0.05)

# Appliquer le test de Student pour chaque caractéristique numérique
for column in numerical_columns:
    if check_conditions(group1, group2, column):
        t_stat, p_value = ttest_ind(group1[column], group2[column])
        print(f"Relation entre {column} et la TARGET :")
        print(f"Statistique du test T de Student : {t_stat}")
        print(f"p-value : {p_value}")
        print("\n")
    else:
        print(f"Les conditions pour effectuer le test T de Student ne sont pas remplies pour {column}.")
        print("\n")
# Out:
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour SK_ID_CURR.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour CNT_CHILDREN.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour AMT_INCOME_TOTAL.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour AMT_CREDIT.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour AMT_ANNUITY.
#
#
# Relation entre AMT_GOODS_PRICE et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour REGION_POPULATION_RELATIVE.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour DAYS_BIRTH.
#
#
# Relation entre DAYS_EMPLOYED et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour DAYS_REGISTRATION.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour DAYS_ID_PUBLISH.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour FLAG_MOBIL.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour FLAG_EMP_PHONE.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour FLAG_WORK_PHONE.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour FLAG_CONT_MOBILE.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour FLAG_PHONE.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour FLAG_EMAIL.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour CNT_FAM_MEMBERS.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour REGION_RATING_CLIENT.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour REGION_RATING_CLIENT_W_CITY.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour HOUR_APPR_PROCESS_START.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour REG_REGION_NOT_LIVE_REGION.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour REG_REGION_NOT_WORK_REGION.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour LIVE_REGION_NOT_WORK_REGION.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour REG_CITY_NOT_LIVE_CITY.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour REG_CITY_NOT_WORK_CITY.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour LIVE_CITY_NOT_WORK_CITY.
#
#
# Relation entre EXT_SOURCE_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre EXT_SOURCE_3 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre OBS_30_CNT_SOCIAL_CIRCLE et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre DEF_30_CNT_SOCIAL_CIRCLE et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre OBS_60_CNT_SOCIAL_CIRCLE et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre DEF_60_CNT_SOCIAL_CIRCLE et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour DAYS_LAST_PHONE_CHANGE.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour FLAG_DOCUMENT_3.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour FLAG_DOCUMENT_5.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour FLAG_DOCUMENT_6.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour FLAG_DOCUMENT_7.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour FLAG_DOCUMENT_8.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour FLAG_DOCUMENT_9.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour FLAG_DOCUMENT_11.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour FLAG_DOCUMENT_13.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour FLAG_DOCUMENT_14.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour FLAG_DOCUMENT_15.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour FLAG_DOCUMENT_16.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour FLAG_DOCUMENT_17.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour FLAG_DOCUMENT_18.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour FLAG_DOCUMENT_19.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour FLAG_DOCUMENT_21.
#
#
# Relation entre AMT_REQ_CREDIT_BUREAU_HOUR et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_REQ_CREDIT_BUREAU_DAY et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_REQ_CREDIT_BUREAU_WEEK et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_REQ_CREDIT_BUREAU_MON et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_REQ_CREDIT_BUREAU_QRT et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_REQ_CREDIT_BUREAU_YEAR et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour MISSING_VALS_TOTAL_APP.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour CREDIT_INCOME_RATIO.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour CREDIT_ANNUITY_RATIO.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour ANNUITY_INCOME_RATIO.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour INCOME_ANNUITY_DIFF.
#
#
# Relation entre CREDIT_GOODS_RATIO et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CREDIT_GOODS_DIFF et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre GOODS_INCOME_RATIO et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre INCOME_EXT_RATIO et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CREDIT_EXT_RATIO et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AGE_EMPLOYED_DIFF et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre EMPLOYED_TO_AGE_RATIO et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour FLAG_CONTACTS_SUM.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour HOUR_PROCESS_CREDIT_MUL.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour CNT_NON_CHILDREN.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour CHILDREN_INCOME_RATIO.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour PER_CAPITA_INCOME.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour REGIONS_RATING_INCOME_MUL.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour REGION_RATING_MAX.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour REGION_RATING_MEAN.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour REGION_RATING_MUL.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour FLAG_REGIONS.
#
#
# Relation entre OBS_30_60_SUM et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre DEF_30_60_SUM et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre OBS_DEF_30_MUL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre OBS_DEF_60_MUL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre SUM_OBS_DEF_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre OBS_30_CREDIT_RATIO et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre OBS_60_CREDIT_RATIO et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre DEF_30_CREDIT_RATIO et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre DEF_60_CREDIT_RATIO et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour SUM_FLAGS_DOCUMENTS.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour DAYS_DETAILS_CHANGE_MUL.
#
#
# Les conditions pour effectuer le test T de Student ne sont pas remplies pour DAYS_DETAILS_CHANGE_SUM.
#
#
# Relation entre AMT_ENQ_SUM et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre ENQ_CREDIT_RATIO et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre DAYS_CREDIT_MEAN_OVERALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CREDIT_DAY_OVERDUE_MEAN_OVERALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
# Relation entre CNT_CREDIT_PROLONG_MEAN_OVERALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_SUM_MEAN_OVERALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_SUM_DEBT_MEAN_OVERALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_SUM_OVERDUE_MEAN_OVERALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre FLAG_OVERDUE_RECENT_MEAN_OVERALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CURRENT_DEBT_TO_CREDIT_RATIO_MEAN_OVERALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CURRENT_CREDIT_DEBT_DIFF_MEAN_OVERALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CURRENCY_currency 1_MEAN_OVERALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CURRENCY_currency 2_MEAN_OVERALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CURRENCY_currency 3_MEAN_OVERALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CURRENCY_currency 4_MEAN_OVERALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CREDIT_ACTIVE_Active_MEAN_OVERALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CREDIT_ACTIVE_Bad debt_MEAN_OVERALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CREDIT_ACTIVE_Closed_MEAN_OVERALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CREDIT_ACTIVE_Sold_MEAN_OVERALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CREDIT_TYPE_Another type of loan_MEAN_OVERALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CREDIT_TYPE_Car loan_MEAN_OVERALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CREDIT_TYPE_Cash loan (non-earmarked)_MEAN_OVERALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CREDIT_TYPE_Consumer credit_MEAN_OVERALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CREDIT_TYPE_Credit card_MEAN_OVERALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CREDIT_TYPE_Interbank credit_MEAN_OVERALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CREDIT_TYPE_Loan for business development_MEAN_OVERALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CREDIT_TYPE_Loan for purchase of shares (margin lending)_MEAN_OVERALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CREDIT_TYPE_Loan for the purchase of equipment_MEAN_OVERALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CREDIT_TYPE_Loan for working capital replenishment_MEAN_OVERALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CREDIT_TYPE_Microloan_MEAN_OVERALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CREDIT_TYPE_Mobile operator loan_MEAN_OVERALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CREDIT_TYPE_Mortgage_MEAN_OVERALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CREDIT_TYPE_Real estate loan_MEAN_OVERALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CREDIT_TYPE_Unknown type of loan_MEAN_OVERALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre MISSING_VALUES_TOTAL_PREV_SUM_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_CONTRACT_TYPE_MEAN_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_CONTRACT_TYPE_LAST_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_ANNUITY_SUM_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_APPLICATION_MEAN_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_APPLICATION_MAX_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_APPLICATION_SUM_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_MEAN_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_MAX_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_SUM_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_DOWN_PAYMENT_SUM_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_GOODS_PRICE_SUM_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre WEEKDAY_APPR_PROCESS_START_MEAN_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre WEEKDAY_APPR_PROCESS_START_MAX_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre WEEKDAY_APPR_PROCESS_START_MIN_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre HOUR_APPR_PROCESS_START_MEAN_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre HOUR_APPR_PROCESS_START_MAX_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre HOUR_APPR_PROCESS_START_MIN_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre FLAG_LAST_APPL_PER_CONTRACT_MEAN_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre FLAG_LAST_APPL_PER_CONTRACT_SUM_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NFLAG_LAST_APPL_IN_DAY_MEAN_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NFLAG_LAST_APPL_IN_DAY_SUM_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_CASH_LOAN_PURPOSE_MEAN_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_CASH_LOAN_PURPOSE_LAST_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_CONTRACT_STATUS_MEAN_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_CONTRACT_STATUS_MAX_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_CONTRACT_STATUS_LAST_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre DAYS_DECISION_MEAN_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre DAYS_DECISION_MAX_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre DAYS_DECISION_MIN_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_PAYMENT_TYPE_MEAN_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_PAYMENT_TYPE_LAST_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CODE_REJECT_REASON_MEAN_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CODE_REJECT_REASON_LAST_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_TYPE_SUITE_MEAN_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_TYPE_SUITE_LAST_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_CLIENT_TYPE_MEAN_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_CLIENT_TYPE_LAST_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_GOODS_CATEGORY_MEAN_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_GOODS_CATEGORY_LAST_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_PORTFOLIO_MEAN_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_PORTFOLIO_LAST_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_PRODUCT_TYPE_MEAN_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_PRODUCT_TYPE_LAST_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CHANNEL_TYPE_MEAN_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CHANNEL_TYPE_LAST_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre SELLERPLACE_AREA_MEAN_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre SELLERPLACE_AREA_MAX_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre SELLERPLACE_AREA_MIN_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_SELLER_INDUSTRY_MEAN_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_SELLER_INDUSTRY_LAST_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CNT_PAYMENT_SUM_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_YIELD_GROUP_MEAN_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
# Relation entre NAME_YIELD_GROUP_LAST_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre PRODUCT_COMBINATION_MEAN_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre PRODUCT_COMBINATION_LAST_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NFLAG_INSURED_ON_APPROVAL_SUM_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_DECLINED_MEAN_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_DECLINED_MAX_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_DECLINED_SUM_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_APPLICATION_RATIO_MEAN_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_APPLICATION_RATIO_MIN_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre INTEREST_DOWNPAYMENT_SUM_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre INTEREST_CREDIT_SUM_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre INTEREST_CREDIT_PRIVILEGED_SUM_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre APPLICATION_AMT_TO_DECISION_RATIO_MEAN_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre APPLICATION_AMT_TO_DECISION_RATIO_MIN_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_APPLICATION_TO_SELLERPLACE_AREA_MEAN_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_APPLICATION_TO_SELLERPLACE_AREA_MAX_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre ANNUITY_SUM_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre ANNUITY_GOODS_SUM_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_HOUR_PROCESS_START_MEAN_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_HOUR_PROCESS_START_SUM_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_NFLAG_LAST_APPL_DAY_MEAN_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_NFLAG_LAST_APPL_DAY_MAX_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_YIELD_GROUP_MEAN_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_YIELD_GROUP_SUM_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_YIELD_GROUP_MIN_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_INTEREST_SUM_LAST_5 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre MISSING_VALUES_TOTAL_PREV_SUM_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_CONTRACT_TYPE_MEAN_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_CONTRACT_TYPE_LAST_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_ANNUITY_SUM_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_APPLICATION_MEAN_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_APPLICATION_MAX_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_APPLICATION_SUM_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_MEAN_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_MAX_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_SUM_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_DOWN_PAYMENT_SUM_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_GOODS_PRICE_SUM_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre WEEKDAY_APPR_PROCESS_START_MEAN_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre WEEKDAY_APPR_PROCESS_START_MAX_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre WEEKDAY_APPR_PROCESS_START_MIN_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre HOUR_APPR_PROCESS_START_MEAN_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre HOUR_APPR_PROCESS_START_MAX_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre HOUR_APPR_PROCESS_START_MIN_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre FLAG_LAST_APPL_PER_CONTRACT_MEAN_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre FLAG_LAST_APPL_PER_CONTRACT_SUM_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NFLAG_LAST_APPL_IN_DAY_MEAN_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NFLAG_LAST_APPL_IN_DAY_SUM_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_CASH_LOAN_PURPOSE_MEAN_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_CASH_LOAN_PURPOSE_LAST_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_CONTRACT_STATUS_MEAN_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_CONTRACT_STATUS_MAX_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_CONTRACT_STATUS_LAST_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre DAYS_DECISION_MEAN_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre DAYS_DECISION_MAX_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre DAYS_DECISION_MIN_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_PAYMENT_TYPE_MEAN_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_PAYMENT_TYPE_LAST_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CODE_REJECT_REASON_MEAN_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CODE_REJECT_REASON_LAST_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_TYPE_SUITE_MEAN_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_TYPE_SUITE_LAST_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_CLIENT_TYPE_MEAN_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_CLIENT_TYPE_LAST_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_GOODS_CATEGORY_MEAN_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_GOODS_CATEGORY_LAST_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_PORTFOLIO_MEAN_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_PORTFOLIO_LAST_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_PRODUCT_TYPE_MEAN_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_PRODUCT_TYPE_LAST_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CHANNEL_TYPE_MEAN_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CHANNEL_TYPE_LAST_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre SELLERPLACE_AREA_MEAN_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre SELLERPLACE_AREA_MAX_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre SELLERPLACE_AREA_MIN_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_SELLER_INDUSTRY_MEAN_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_SELLER_INDUSTRY_LAST_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CNT_PAYMENT_SUM_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_YIELD_GROUP_MEAN_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_YIELD_GROUP_LAST_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre PRODUCT_COMBINATION_MEAN_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre PRODUCT_COMBINATION_LAST_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NFLAG_INSURED_ON_APPROVAL_SUM_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_DECLINED_MEAN_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
# Relation entre AMT_DECLINED_MAX_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_DECLINED_SUM_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_APPLICATION_RATIO_MEAN_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_APPLICATION_RATIO_MIN_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre INTEREST_DOWNPAYMENT_SUM_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre INTEREST_CREDIT_SUM_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre INTEREST_CREDIT_PRIVILEGED_SUM_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre APPLICATION_AMT_TO_DECISION_RATIO_MEAN_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre APPLICATION_AMT_TO_DECISION_RATIO_MIN_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_APPLICATION_TO_SELLERPLACE_AREA_MEAN_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_APPLICATION_TO_SELLERPLACE_AREA_MAX_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre ANNUITY_SUM_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre ANNUITY_GOODS_SUM_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_HOUR_PROCESS_START_MEAN_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_HOUR_PROCESS_START_SUM_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_NFLAG_LAST_APPL_DAY_MEAN_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_NFLAG_LAST_APPL_DAY_MAX_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_YIELD_GROUP_MEAN_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_YIELD_GROUP_SUM_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_YIELD_GROUP_MIN_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_INTEREST_SUM_FIRST_2 et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre MISSING_VALUES_TOTAL_PREV_SUM_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_CONTRACT_TYPE_MEAN_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_CONTRACT_TYPE_LAST_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_ANNUITY_SUM_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_APPLICATION_MEAN_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_APPLICATION_MAX_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_APPLICATION_SUM_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_MEAN_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_MAX_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_SUM_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_DOWN_PAYMENT_SUM_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_GOODS_PRICE_SUM_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre WEEKDAY_APPR_PROCESS_START_MEAN_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre WEEKDAY_APPR_PROCESS_START_MAX_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre WEEKDAY_APPR_PROCESS_START_MIN_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre HOUR_APPR_PROCESS_START_MEAN_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre HOUR_APPR_PROCESS_START_MAX_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre HOUR_APPR_PROCESS_START_MIN_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre FLAG_LAST_APPL_PER_CONTRACT_MEAN_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre FLAG_LAST_APPL_PER_CONTRACT_SUM_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NFLAG_LAST_APPL_IN_DAY_MEAN_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NFLAG_LAST_APPL_IN_DAY_SUM_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_CASH_LOAN_PURPOSE_MEAN_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_CASH_LOAN_PURPOSE_LAST_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_CONTRACT_STATUS_MEAN_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_CONTRACT_STATUS_MAX_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_CONTRACT_STATUS_LAST_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre DAYS_DECISION_MEAN_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre DAYS_DECISION_MAX_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre DAYS_DECISION_MIN_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_PAYMENT_TYPE_MEAN_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_PAYMENT_TYPE_LAST_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CODE_REJECT_REASON_MEAN_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CODE_REJECT_REASON_LAST_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_TYPE_SUITE_MEAN_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_TYPE_SUITE_LAST_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_CLIENT_TYPE_MEAN_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_CLIENT_TYPE_LAST_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_GOODS_CATEGORY_MEAN_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_GOODS_CATEGORY_LAST_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_PORTFOLIO_MEAN_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_PORTFOLIO_LAST_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_PRODUCT_TYPE_MEAN_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_PRODUCT_TYPE_LAST_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CHANNEL_TYPE_MEAN_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CHANNEL_TYPE_LAST_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre SELLERPLACE_AREA_MEAN_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre SELLERPLACE_AREA_MAX_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre SELLERPLACE_AREA_MIN_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_SELLER_INDUSTRY_MEAN_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_SELLER_INDUSTRY_LAST_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre CNT_PAYMENT_SUM_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_YIELD_GROUP_MEAN_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NAME_YIELD_GROUP_LAST_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre PRODUCT_COMBINATION_MEAN_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre PRODUCT_COMBINATION_LAST_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre NFLAG_INSURED_ON_APPROVAL_SUM_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_DECLINED_MEAN_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
# Relation entre AMT_DECLINED_MAX_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_DECLINED_SUM_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_APPLICATION_RATIO_MEAN_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_APPLICATION_RATIO_MIN_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre INTEREST_DOWNPAYMENT_SUM_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre INTEREST_CREDIT_SUM_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre INTEREST_CREDIT_PRIVILEGED_SUM_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre APPLICATION_AMT_TO_DECISION_RATIO_MEAN_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre APPLICATION_AMT_TO_DECISION_RATIO_MIN_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_APPLICATION_TO_SELLERPLACE_AREA_MEAN_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_APPLICATION_TO_SELLERPLACE_AREA_MAX_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre ANNUITY_SUM_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre ANNUITY_GOODS_SUM_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_HOUR_PROCESS_START_MEAN_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_HOUR_PROCESS_START_SUM_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_NFLAG_LAST_APPL_DAY_MEAN_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_NFLAG_LAST_APPL_DAY_MAX_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_YIELD_GROUP_MEAN_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_YIELD_GROUP_SUM_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_CREDIT_YIELD_GROUP_MIN_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan
#
#
# Relation entre AMT_INTEREST_SUM_ALL et la TARGET :
# Statistique du test T de Student : nan
# p-value : nan

# %%
# créer une colonne target de type numerique pour pouvoir voir la relation entre les features numériques et la target
data['Target_Numerique'] = data['TARGET'].astype('int')

# %%
# Calculer les corrélations
correlation = data.corr()['Target_Numerique']

# %%
correlation
# Out:
# SK_ID_CURR                        -0.002111
# CNT_CHILDREN                       0.019189
# AMT_INCOME_TOTAL                  -0.003982
# AMT_CREDIT                        -0.030371
# AMT_ANNUITY                       -0.012818
#                                      ...
# AMT_CREDIT_YIELD_GROUP_MEAN_ALL   -0.002020
# AMT_CREDIT_YIELD_GROUP_SUM_ALL     0.017630
# AMT_CREDIT_YIELD_GROUP_MIN_ALL    -0.014408
# AMT_INTEREST_SUM_ALL               0.031076
# Target_Numerique                   1.000000
# Name: Target_Numerique, Length: 361, dtype: float64

# %%
 # Supprimer les caractéristiques dont la corrélation est entre -0.01 et 0.01
to_drop = correlation[(correlation > -0.01) & (correlation < 0.01)].index
df_allegé = data.drop(to_drop, axis=1)

# %%
df_allegé.head()
# Out:
#   TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 0      1         Cash loans           M            N               Y
# 1      0         Cash loans           F            N               N
# 2      0    Revolving loans           M            Y               Y
# 3      0         Cash loans           F            N               Y
# 4      0         Cash loans           M            N               Y
#
#    CNT_CHILDREN  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE NAME_TYPE_SUITE  \
# 0             0    406597.5      24700.5         351000.0   Unaccompanied
# 1             0   1293502.5      35698.5        1129500.0          Family
# 2             0    135000.0       6750.0         135000.0   Unaccompanied
# 3             0    312682.5      29686.5         297000.0   Unaccompanied
# 4             0    513000.0      21865.5         513000.0   Unaccompanied
#
#    ... AMT_CREDIT_APPLICATION_RATIO_MIN_ALL INTEREST_DOWNPAYMENT_SUM_ALL  \
# 0  ...                             1.000000                     0.000000
# 1  ...                             0.868825                   688.917198
# 2  ...                             1.207699                  1030.356951
# 3  ...                             0.000000                 14885.329486
# 4  ...                             0.791139                  1115.692435
#
#   ANNUITY_SUM_ALL ANNUITY_GOODS_SUM_ALL  \
# 0    7.460622e+03          7.460622e+03
# 1    1.501007e+05          1.369840e+05
# 2    5.026487e+03          6.070485e+03
# 3    2.700008e+10          2.700008e+10
# 4    4.935926e+04          4.617637e+04
#
#    AMT_CREDIT_HOUR_PROCESS_START_MEAN_ALL  \
# 0                              1611495.00
# 1                              6459408.00
# 2                               100530.00
# 3                              4214934.00
# 4                              1935207.75
#
#    AMT_CREDIT_NFLAG_LAST_APPL_DAY_MEAN_ALL  AMT_CREDIT_YIELD_GROUP_SUM_ALL  \
# 0                                179055.00                        358110.0
# 1                                484191.00                       3321837.0
# 2                                 20106.00                         60318.0
# 3                                291695.50                       6233589.0
# 4                                166638.75                       3224776.5
#
#    AMT_CREDIT_YIELD_GROUP_MIN_ALL  AMT_INTEREST_SUM_ALL  Target_Numerique
# 0                        358110.0              42987.60                 1
# 1                        204160.5             195964.65                 0
# 2                         60318.0               1323.00                 0
# 3                             0.0            1205267.76                 0
# 4                         58464.0             640477.62                 0
#
# [5 rows x 238 columns]

# %%
correlation_matrix = data.corr()

# %%
# Plot
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Matrice de corrélation")
plt.show()
